# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:10
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive
# Out:
# /content/drive/My Drive

# %%
# !git clone https://github.com/prometheus-eval/prometheus.git
# Out:
# Cloning into 'prometheus'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 221 (delta 9), reused 5 (delta 5), pack-reused 201 (from 1)
# Receiving objects: 100% (221/221), 18.17 MiB | 12.07 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Updating files: 100% (126/126), done.
# fatal: cannot exec '/content/drive/My Drive/prometheus/.git/hooks/post-checkout': Permission denied
# Encountered 7 file(s) that should have been pointers, but weren't:
# 	evaluation/benchmark/data/feedback_collection_ood_test.json
# 	evaluation/benchmark/data/feedback_collection_test.json
# 	evaluation/benchmark/data/flask_eval.json
# 	evaluation/benchmark/data/hhh_alignment_eval.json
# 	evaluation/benchmark/data/mt_bench_eval.json
# 	evaluation/benchmark/data/mt_bench_human_judgement_eval.json
# 	evaluation/benchmark/data/vicuna_eval.json

# %%
cd prometheus
# Out:
# /content/drive/MyDrive/prometheus

# %%
# 가상환경 생성

# !conda create -n env python=3.10
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/env
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h4bc722e_7         247 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     ld_impl_linux-64-2.43      |       h712a8e2_1         654 KB  conda-forge
#     libgcc-14.1.0              |       h77fa898_1         827 KB  conda-forge
#     libgcc-ng-14.1.0           |       h69a702a_1          51 KB  conda-forge
#     libgomp-14.1.0             |       h77fa898_1         449 KB  conda-forge
#     libsqlite-3.46.1           |       hadc24fc_0         845 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libzlib-1.3.1              |       h4ab18f5_1          60 KB  conda-forge
#     ncurses-6.5                |       he02047a_1         868 KB  conda-forge
#     openssl-3.3.2              |       hb9d3cd8_0         2.8 MB  conda-forge
#     pip-24.2                   |     pyh8b19718_1         1.2 MB  conda-forge
#     python-3.10.15             |h4a871b0_1_cpython        24.0 MB  conda-forge
#     setuptools-75.1.0          |     pyhd8ed1ab_0         759 KB  conda-forge
#     tzdata-2024a               |       h8827d51_1         121 KB  conda-forge
#     wheel-0.44.0               |     pyhd8ed1ab_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        33.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.8.30-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.43-h712a8e2_1
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc             conda-forge/linux-64::libgcc-14.1.0-h77fa898_1
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.1.0-h69a702a_1
#   libgomp            conda-forge/linux-64::libgomp-14.1.0-h77fa898_1
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.46.1-hadc24fc_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-h4ab18f5_1
#   ncurses            conda-forge/linux-64::ncurses-6.5-he02047a_1
#   openssl            conda-forge/linux-64::openssl-3.3.2-hb9d3cd8_0
#   pip                conda-forge/noarch::pip-24.2-pyh8b19718_1
#   python             conda-forge/linux-64::python-3.10.15-h4a871b0_1_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         conda-forge/noarch::setuptools-75.1.0-pyhd8ed1ab_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   tzdata             conda-forge/noarch::tzdata-2024a-h8827d51_1
#   wheel              conda-forge/noarch::wheel-0.44.0-pyhd8ed1ab_0
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#
#
#
# Downloading and Extracting Packages:
# python-3.10.15       | 24.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.3.2        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# pip-24.2             | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ncurses-6.5          | 868 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libsqlite-3.46.1     | 845 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libgcc-14.1.0        | 827 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# setuptools-75.1.0    | 759 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 121 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.44.0         | 57 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.15       | 24.0 MB   | :   2% 0.018205533886710364/1 [00:00<00:05,  5.50s/it]
#
# pip-24.2             | 1.2 MB    | :  40% 0.3970351606170071/1 [00:00<00:00,  3.97it/s]
#
#
#
# libsqlite-3.46.1     | 845 KB    | :   2% 0.01893635562993664/1 [00:00<00:06,  6.16s/it]
#
#
#
#
# libgcc-14.1.0        | 827 KB    | :   2% 0.01935773529620265/1 [00:00<00:08,  8.36s/it]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | :   2% 0.0244677546534133/1 [00:00<00:06,  6.86s/it]
#
#
#
#
#
# python-3.10.15       | 24.0 MB   | :  16% 0.16450000261920436/1 [00:00<00:00,  1.08s/it]
#
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | :   4% 0.03560051975368195/1 [00:00<00:06,  6.85s/it]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | :   6% 0.06481448515129577/1 [00:00<00:03,  3.93s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | :  10% 0.10304208096702577/1 [00:00<00:02,  2.74s/it]
#
#
#
#
#
#
#
#
#
#
# python-3.10.15       | 24.0 MB   | :  26% 0.25682806733037833/1 [00:00<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | :  16% 0.163198629386511/1 [00:00<00:01,  1.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.44.0         | 57 KB     | :  28% 0.2796620295297431/1 [00:00<00:00,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | :  27% 0.2660863351414558/1 [00:00<00:00,  1.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.15       | 24.0 MB   | :  91% 0.9076759037802739/1 [00:00<00:00,  1.53it/s]
# openssl-3.3.2        | 2.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.41it/s]
# openssl-3.3.2        | 2.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.41it/s]
#
#
#
# libsqlite-3.46.1     | 845 KB    | : 100% 1.0/1 [00:00<00:00,  1.34it/s]
#
#
#
# libsqlite-3.46.1     | 845 KB    | : 100% 1.0/1 [00:00<00:00,  1.34it/s]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | : 100% 1.0/1 [00:00<00:00,  1.19it/s]
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 654 KB    | : 100% 1.0/1 [00:00<00:00,  1.19it/s]
#
# pip-24.2             | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.06s/it]
#
# pip-24.2             | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.06s/it]
#
#
#
#
# libgcc-14.1.0        | 827 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
# libgcc-14.1.0        | 827 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 247 KB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
# libgomp-14.1.0       | 449 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | : 100% 1.0/1 [00:01<00:00,  1.30s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 155 KB    | : 100% 1.0/1 [00:01<00:00,  1.30s/it]
#
#
#
#
#
# setuptools-75.1.0    | 759 KB    | : 100% 1.0/1 [00:01<00:00,  1.59s/it]
#
#
#
#
#
# setuptools-75.1.0    | 759 KB    | : 100% 1.0/1 [00:01<00:00,  1.59s/it]
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
# libxcrypt-4.4.36     | 98 KB     | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.44.0         | 57 KB     | : 100% 1.0/1 [00:01<00:00,  1.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.44.0         | 57 KB     | : 100% 1.0/1 [00:01<00:00,  1.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | : 100% 1.0/1 [00:01<00:00,  1.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 60 KB     | : 100% 1.0/1 [00:01<00:00,  1.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 51 KB     | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 51 KB     | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 121 KB    | : 100% 1.0/1 [00:01<00:00,  1.97s/it]
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 121 KB    | : 100% 1.0/1 [00:01<00:00,  1.97s/it]
#
#
# ncurses-6.5          | 868 KB    | : 100% 1.0/1 [00:02<00:00,  2.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !source ~/.bashrc

# %%
# !conda init
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.10/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !source activate env

# %%
# 활성화된 가상환경 확인

# !conda info --envs
# Out:
# # conda environments:
# #
# base                     /usr/local
# env                      /usr/local/envs/env

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.34.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: loralib in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.44.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (0.13.0)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (4.44.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: py7zr in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.22.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.14.1)
# Requirement already satisfied: optimum in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.22.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.10/site-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 2)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 2)) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 2)) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/site-packages (from datasets->-r requirements.txt (line 6)) (3.10.8)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/site-packages (from fire->-r requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/site-packages (from transformers>=4.31.0->-r requirements.txt (line 9)) (2024.9.11)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/site-packages (from transformers>=4.31.0->-r requirements.txt (line 9)) (0.19.1)
# Requirement already satisfied: texttable in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (3.21.0)
# Requirement already satisfied: pyzstd>=0.15.9 in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (0.16.1)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.10/site-packages (from py7zr->-r requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/site-packages (from optimum->-r requirements.txt (line 13)) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/site-packages (from aiohttp->datasets->-r requirements.txt (line 6)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/site-packages (from aiohttp->datasets->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/site-packages (from aiohttp->datasets->-r requirements.txt (line 6)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/site-packages (from aiohttp->datasets->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/site-packages (from aiohttp->datasets->-r requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/site-packages (from aiohttp->datasets->-r requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/site-packages (from aiohttp->datasets->-r requirements.txt (line 6)) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 6)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 6)) (2023.11.17)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/site-packages (from transformers[sentencepiece]<4.45.0,>=4.29->optimum->-r requirements.txt (line 13)) (5.28.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/site-packages (from coloredlogs->optimum->-r requirements.txt (line 13)) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2->torch>=2.0.1->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2024.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/site-packages (from sympy->torch>=2.0.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->-r requirements.txt (line 6)) (1.16.0)

# %%
cd evaluation
# Out:
# /content/drive/MyDrive/prometheus/evaluation

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: fineGrained).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- ----------
# accelerate              0.34.2
# appdirs                 1.4.4
# archspec                0.2.2
# bitsandbytes            0.44.1
# boltons                 23.1.1
# Brotli                  1.1.0
# certifi                 2023.11.17
# cffi                    1.16.0
# charset-normalizer      3.3.2
# colorama                0.4.6
# conda                   23.11.0
# conda-libmamba-solver   23.12.0
# conda-package-handling  2.2.0
# conda_package_streaming 0.9.0
# datasets                3.0.1
# distro                  1.8.0
# fire                    0.7.0
# idna                    3.6
# jsonpatch               1.33
# jsonpointer             2.4
# libmambapy              1.5.5
# loralib                 0.1.2
# mamba                   1.5.5
# MarkupSafe              2.1.5
# menuinst                2.0.1
# mpmath                  1.3.0
# nvidia-nvjitlink-cu12   12.6.77
# optimum                 1.22.0
# packaging               23.2
# peft                    0.13.0
# pip                     23.3.2
# platformdirs            4.1.0
# pluggy                  1.3.0
# py7zr                   0.22.0
# pycosat                 0.6.6
# pycparser               2.21
# PySocks                 1.7.1
# requests                2.31.0
# ruamel.yaml             0.18.5
# ruamel.yaml.clib        0.2.7
# scipy                   1.14.1
# sentencepiece           0.2.0
# setuptools              68.2.2
# torch                   2.4.1
# tqdm                    4.66.1
# transformers            4.45.1
# truststore              0.8.0
# typing_extensions       4.12.2
# urllib3                 2.1.0
# wheel                   0.42.0
# zstandard               0.22.0

# %%
# !python run.py
# Out:
# Loading checkpoint shards: 100% 6/6 [00:08<00:00,  1.43s/it]
# Some parameters are on the meta device because they were offloaded to the cpu.
# <s>
# ###Task Description:
# An instruction (might include an Input inside it), a response to evaluate, a reference answer that gets a score of 5, and a score rubric representing a evaluation criteria are given.
# 1. Write a detailed feedback that assess the quality of the response strictly based on the given score rubric, not evaluating in general.
# 2. After writing a feedback, write a score that is an integer between 1 and 5. You should refer to the score rubric.
# 3. The output format should look as follows: "Feedback: (write a feedback for criteria) [RESULT] (an integer number between 1 and 5)"
# 4. Please do not generate any other opening, closing, and explanations.
#
# ###The instruction to evaluate:
# Explain the significance of Newton's laws of motion.
#
# ###Response to evaluate:
# Newton's laws describe how objects move and interact.
#
# ###Reference Answer (Score 5):
# Newton's laws explain the fundamental principles governing the motion of objects in classical mechanics, with applications in various fields.
#
# ###Score Rubrics:
# Relevance to the topic, completeness, and accuracy.
# Score 1: Fails to address the question.
# Score 2: Partial or superficial response.
# Score 3: Adequate response but with minor omissions.
# Score 4: Thorough response with minor errors.
# Score 5: Comprehensive and highly accurate response.
#
# ###Feedback:
# The response provides a superficial understanding of Newton's laws without explaining the significance or impact. It merely states that the laws describe the movement and interaction of objects without offering any insight into their importance or application in various fields, thereby lacking depth and detail. This response does not completely address the instruction and fails to highlight the broader implications and relevance of the laws in different contexts, such as classical mechanics, engineering, physics, etc. So the overall score is 2. [RESULT] 2</s>
